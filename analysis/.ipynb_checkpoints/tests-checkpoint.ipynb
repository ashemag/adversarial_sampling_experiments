# %% [markdown]
# Add root directory "adversarial_sampling_experiments" to system path so that you can import modules outside of the "analysis" package.

# %%
import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
    print("added root dir to sys.path: ",module_path)
else:
    print("root dir: ",module_path)
# Out:
# added root dir to sys.path:  C:\mlp_new\adversarial_sampling_experiments

# %% [markdown]
# Checking the contents of the cifar10 data provider.

# %%
from data_providers import CIFAR10
import globals

data_dir = os.path.join(globals.ROOT_DIR,'data')
cifar10 = CIFAR10(root=data_dir,set_name='val',download=False)
images = cifar10.data
labels = cifar10.labels

img = images[0]
label = labels[0]

print("return types. images: ",type(images)," labels: ",type(labels))
print("shape of batch of labels: ",labels.shape)
print("shape of batch of images: ",images.shape)
# Out:
# return types. images:  <class 'numpy.ndarray'>  labels:  <class 'numpy.ndarray'>
# shape of batch of labels:  (2500,)
# shape of batch of images:  (2500, 32, 32, 3)

# %% [markdown]
# ### Display a single image

# %%
from PIL import Image
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.imshow(img) # imshow accepts numpy array
ax.set_yticks([])
ax.set_xticks([])

# fig.show()
# Out:
# []

# %% [markdown]
# ### View multiple images from a specific class
# Note: It is also possible to view a random selection of images. Simply drop the **label** argument from **.grid**.

# %%
from data_viewer import ImageDataViewer
viewer = ImageDataViewer((images,labels))
fig, axs = viewer.grid(shape=(4,4),label=0)

# %% [markdown]
# ### View worst performing images from a specific class
